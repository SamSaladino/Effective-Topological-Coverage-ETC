# %%
import networkx as nx
import matplotlib.pyplot as plt
from pathlib import Path
from etc.utils import GraphLabelPropagation
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       2 import matplotlib.pyplot as plt
#       3 from pathlib import Path
# ----> 4 from etc.utils import GraphLabelPropagation
#
# File ~/Documents/ETC/Effective-Topological-Coverage-ETC/src/etc/__init__.py:2
#       1 from . import utils
# ----> 2 from . import diffusion
#       3 from . import sampling
#       4 from . import coverage
#
# ImportError: cannot import name 'diffusion' from partially initialized module 'etc' (most likely due to a circular import) (/home/scostagonza/Documents/ETC/Effective-Topological-Coverage-ETC/src/etc/__init__.py)

# %%
# Get the notebook's directory and go up to project root
notebook_dir = Path().resolve()
project_root = notebook_dir.parent
gml_path = project_root / "data" / "resources" / "generated" / "modified_graph.gml"

# %%
G = nx.read_gml(gml_path)

# %%
path = "/home/scostagonza/Documents/MappingEdata/mapping-data1/resources/nonEstelle.txt"

# %%
# Load non-identified metabolites from txt file
non_identified_path = Path(path)
with open(non_identified_path, "r") as f:
    non_identified = {line.strip() for line in f if line.strip()}

# %%
# Set labels: 0 for non-identified, 1 for others
labels = {node: 0 if node in non_identified else 1 for node in G.nodes()}
glp = GraphLabelPropagation(G)
glp.labels = labels

# Run custom LPA
lpa_labels = glp.custom_lpa(iterations=100)
glp.plot(labels=lpa_labels, title="Labels After Custom LPA")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 # Set labels: 0 for non-identified, 1 for others
#       2 labels = {node: 0 if node in non_identified else 1 for node in G.nodes()}
# ----> 3 glp = GraphLabelPropagation(G)
#       4 glp.labels = labels
#       6 # Run custom LPA
#
# NameError: name 'GraphLabelPropagation' is not defined
